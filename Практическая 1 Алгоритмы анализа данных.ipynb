# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

X.shape

y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

W = np.random.normal(size=(X.shape[1]))
W
n = X.shape[0]

#ИЗМЕНЕНО: eta, n_iter
eta = 1e-5 
n_iter = 900
#конец изменений

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 1e-05
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [1.00108 0.50377], MSE = 3047.75
# Iteration #10: W_new = [1.01088672 0.53798047], MSE = 3033.67
# Iteration #20: W_new = [1.01978413 0.56898416], MSE = 3020.95
# Iteration #30: W_new = [1.02785801 0.59708963], MSE = 3009.45
# Iteration #40: W_new = [1.03518581 0.62257436], MSE = 2999.05
# Iteration #50: W_new = [1.04183747 0.64568813], MSE = 2989.64
# Iteration #60: W_new = [1.04787622 0.66665599], MSE = 2981.11
# Iteration #70: W_new = [1.05335921 0.68568083], MSE = 2973.4
# Iteration #80: W_new = [1.05833816 0.70294576], MSE = 2966.4
# Iteration #90: W_new = [1.06285986 0.71861607], MSE = 2960.07
# Iteration #100: W_new = [1.06696668 0.73284112], MSE = 2954.32
# Iteration #110: W_new = [1.07069701 0.7457559 ], MSE = 2949.12
# Iteration #120: W_new = [1.07408563 0.75748252], MSE = 2944.39
# Iteration #130: W_new = [1.07716405 0.76813145], MSE = 2940.11
# Iteration #140: W_new = [1.07996085 0.77780268], MSE = 2936.22
# Iteration #150: W_new = [1.08250193 0.78658678], MSE = 2932.69
# Iteration #160: W_new = [1.0848108  0.79456578], MSE = 2929.49
# Iteration #170: W_new = [1.08690877 0.801814  ], MSE = 2926.58
# Iteration #180: W_new = [1.0888152  0.80839883], MSE = 2923.94
# Iteration #190: W_new = [1.09054764 0.81438135], MSE = 2921.55
# Iteration #200: W_new = [1.09212202 0.81981695], MSE = 2919.37
# Iteration #210: W_new = [1.09355281 0.8247559 ], MSE = 2917.39
# Iteration #220: W_new = [1.09485315 0.82924376], MSE = 2915.6
# Iteration #230: W_new = [1.09603496 0.83332193], MSE = 2913.97
# Iteration #240: W_new = [1.09710907 0.83702793], MSE = 2912.49
# Iteration #250: W_new = [1.09808532 0.84039585], MSE = 2911.14
# Iteration #260: W_new = [1.09897264 0.84345663], MSE = 2909.92
# Iteration #270: W_new = [1.09977914 0.84623835], MSE = 2908.81
# Iteration #280: W_new = [1.10051221 0.84876653], MSE = 2907.8
# Iteration #290: W_new = [1.10117853 0.85106433], MSE = 2906.88
# Iteration #300: W_new = [1.1017842  0.85315278], MSE = 2906.05
# Iteration #310: W_new = [1.10233474 0.85505101], MSE = 2905.29
# Iteration #320: W_new = [1.10283517 0.85677636], MSE = 2904.6
# Iteration #330: W_new = [1.10329006 0.8583446 ], MSE = 2903.98
# Iteration #340: W_new = [1.10370356 0.85977007], MSE = 2903.41
# Iteration #350: W_new = [1.10407943 0.86106577], MSE = 2902.89
# Iteration #360: W_new = [1.10442111 0.86224354], MSE = 2902.42
# Iteration #370: W_new = [1.10473171 0.86331413], MSE = 2902.0
# Iteration #380: W_new = [1.10501405 0.86428728], MSE = 2901.61
# Iteration #390: W_new = [1.1052707  0.86517189], MSE = 2901.25
# Iteration #400: W_new = [1.10550402 0.86597601], MSE = 2900.93
# Iteration #410: W_new = [1.10571611 0.86670698], MSE = 2900.64
# Iteration #420: W_new = [1.10590892 0.86737145], MSE = 2900.38
# Iteration #430: W_new = [1.10608418 0.86797547], MSE = 2900.14
# Iteration #440: W_new = [1.10624351 0.86852455], MSE = 2899.92
# Iteration #450: W_new = [1.10638835 0.86902369], MSE = 2899.72
# Iteration #460: W_new = [1.10652002 0.86947743], MSE = 2899.54
# Iteration #470: W_new = [1.10663972 0.8698899 ], MSE = 2899.37
# Iteration #480: W_new = [1.10674853 0.87026487], MSE = 2899.23
# Iteration #490: W_new = [1.10684745 0.87060573], MSE = 2899.09
# Iteration #500: W_new = [1.10693737 0.87091559], MSE = 2898.97
# Iteration #510: W_new = [1.10701912 0.87119728], MSE = 2898.85
# Iteration #520: W_new = [1.10709343 0.87145335], MSE = 2898.75
# Iteration #530: W_new = [1.10716099 0.87168614], MSE = 2898.66
# Iteration #540: W_new = [1.10722241 0.87189776], MSE = 2898.57
# Iteration #550: W_new = [1.10727824 0.87209014], MSE = 2898.5
# Iteration #560: W_new = [1.10732899 0.87226503], MSE = 2898.43
# Iteration #570: W_new = [1.10737513 0.87242401], MSE = 2898.37
# Iteration #580: W_new = [1.10741708 0.87256854], MSE = 2898.31
# Iteration #590: W_new = [1.10745521 0.87269993], MSE = 2898.26
# Iteration #600: W_new = [1.10748987 0.87281937], MSE = 2898.21
# Iteration #610: W_new = [1.10752139 0.87292796], MSE = 2898.16
# Iteration #620: W_new = [1.10755004 0.87302667], MSE = 2898.13
# Iteration #630: W_new = [1.10757608 0.8731164 ], MSE = 2898.09
# Iteration #640: W_new = [1.10759976 0.87319798], MSE = 2898.06
# Iteration #650: W_new = [1.10762128 0.87327214], MSE = 2898.03
# Iteration #660: W_new = [1.10764085 0.87333956], MSE = 2898.0
# Iteration #670: W_new = [1.10765863 0.87340085], MSE = 2897.98
# Iteration #680: W_new = [1.1076748  0.87345657], MSE = 2897.95
# Iteration #690: W_new = [1.10768951 0.87350722], MSE = 2897.93
# Iteration #700: W_new = [1.10770287 0.87355327], MSE = 2897.92
# Iteration #710: W_new = [1.10771502 0.87359513], MSE = 2897.9
# Iteration #720: W_new = [1.10772606 0.87363318], MSE = 2897.88
# Iteration #730: W_new = [1.1077361  0.87366778], MSE = 2897.87
# Iteration #740: W_new = [1.10774523 0.87369923], MSE = 2897.86
# Iteration #750: W_new = [1.10775353 0.87372782], MSE = 2897.85
# Iteration #760: W_new = [1.10776107 0.87375381], MSE = 2897.84
# Iteration #770: W_new = [1.10776793 0.87377744], MSE = 2897.83
# Iteration #780: W_new = [1.10777417 0.87379892], MSE = 2897.82
# Iteration #790: W_new = [1.10777983 0.87381845], MSE = 2897.81
# Iteration #800: W_new = [1.10778499 0.8738362 ], MSE = 2897.8
# Iteration #810: W_new = [1.10778967 0.87385234], MSE = 2897.8
# Iteration #820: W_new = [1.10779393 0.87386701], MSE = 2897.79
# Iteration #830: W_new = [1.1077978  0.87388035], MSE = 2897.79
# Iteration #840: W_new = [1.10780132 0.87389247], MSE = 2897.78
# Iteration #850: W_new = [1.10780452 0.8739035 ], MSE = 2897.78
# Iteration #860: W_new = [1.10780743 0.87391352], MSE = 2897.77
# Iteration #870: W_new = [1.10781007 0.87392263], MSE = 2897.77
# Iteration #880: W_new = [1.10781247 0.87393091], MSE = 2897.77
# Iteration #890: W_new = [1.10781466 0.87393844], MSE = 2897.76
